# %%
# run this in jupyter
import micropip
await micropip.install("pint")

# %% [markdown]
# ## Basic Arithmetic
#
# ```
# Operators: / * + -
# Exponential: ** (e.g. 3 ** 2 = 9)
# Parentheses: (3 + 5) / 2 = 4
# ```

# %%
5 + 2
# Out:
# 7

# %%
# use the previous output
Out[2] * 7
# Out:
# 49

# %%
# order of operations applies
(12 - 4) / 2 ** 2
# Out:
# 2.0

# %% [markdown]
# ## Plotting with matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# create 1000 equally spaced points between -10 and 10
x = np.linspace(-10, 10, 1000)

# calculate the y value for each element of the x vector
y = x**2 + 2*x + 2  

fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# ## Units with pint

# %%
# https://pint.readthedocs.io/en/0.24.3/getting/tutorial.html#string-formatting
from pint import UnitRegistry
ureg = UnitRegistry()

xf = 25.0 * ureg.meter
xi = -10.0 * ureg.meter
t = 6.0 * ureg.second

v = (xf - xi) / t
print(f'The velocity is: {v:~.2H}')
# Out:
# The velocity is: 5.8 m/s

# %%
import matplotlib.lines
import matplotlib.pyplot as plt


vec1 = matplotlib.lines.Line2D([0, 10], [0, 5], markevery=[1], marker="^")

fig, ax = plt.subplots()
ax.set_xbound(-5, 15)
ax.set_ybound(-5, 15)
ax.add_line(vec1)
